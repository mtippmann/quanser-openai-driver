# %%
import matplotlib.pyplot as plt

from scipy.integrate import odeint
import numpy as np
import math

from gym_brt.quanser import QubeHardware, QubeSimulator
from gym_brt.quanser.qube_interfaces import forward_model_ode

from gym_brt.control import (
    zero_policy,
    constant_policy,
    random_policy,
    square_wave_policy,
    pd_control_policy,
    flip_and_hold_policy,
    square_wave_flip_and_hold_policy,
)

# %% [markdown]
# # Helper functions

# %%
# Run on the hardware
def run_qube(begin_up, policy, nsteps, frequency, integration_steps):
    with QubeHardware(frequency=frequency, max_voltage=3.0) as qube:
        
        if begin_up is True:
            s = qube.reset_up()
        elif begin_up is False:
            s = qube.reset_down()
        
        # Wait for a little bit before reading the initial state
        for _ in range(15):
            a = random_policy(s)
            s = qube.step(a)

        init_state = s
        a = policy(s, step=0)
        s_hist = [s]
        a_hist = [a]

        for i in range(nsteps):
            s = qube.step(a)
            a = policy(s, step=i+1, frequency=frequency)

            s_hist.append(s) # States
            a_hist.append(a) # Actions

        # Return a 2d array, hist[n,d] gives the nth timestep and the dth dimension
        # Dims are ordered as: ['Theta', 'Alpha', 'Theta dot', 'Alpha dot', 'Action']
        return np.concatenate((np.array(s_hist), np.array(a_hist)), axis=1), init_state

def run_sim(init_state, policy, nsteps, frequency, integration_steps):
    with QubeSimulator(
        forward_model=forward_model_ode,
        frequency=frequency,
        integration_steps=integration_steps,
        max_voltage=3.0,
    ) as qube:
        qube.state = np.asarray(init_state, dtype=np.float64)  # Set the initial state of the simulator

        s = init_state
        a = policy(s, step=0)
        s_hist = [s]
        a_hist = [a]

        for i in range(nsteps):
            s = qube.step(a)
            a = policy(s, step=i+1, frequency=frequency)

            s_hist.append(s) # States
            a_hist.append(a) # Actions

        # Return a 2d array, hist[n,d] gives the nth timestep and the dth dimension
        # Dims are ordered as: ['Theta', 'Alpha', 'Theta dot', 'Alpha dot', 'Action']
        return np.concatenate((np.array(s_hist), np.array(a_hist)), axis=1)

# %%
def plot_results(hists, labels, colors=None, normalize=None):
    state_dims = ['Theta', 'Alpha', 'Theta dot', 'Alpha dot', 'Action']
    
    f, (ax1, ax2, ax3, ax4, ax5) = plt.subplots(5, 1, sharex=True)
    for i, ax in enumerate((ax1, ax2, ax3, ax4, ax5)):
        
        # Normalize to be between 0 and 2pi
        if normalize is not None:
            if state_dims[i].lower() in normalize:
                for hist in hists:
                    hist[:,i] %= 2 * np.pi

        # Plot with specific colors
        if colors is not None:
            for hist, label, color in zip(hists, labels, colors):
                ax.plot(hist[:,i], label=label, color=color)

        # Default colors
        else:
            for hist, label in zip(hists, labels):
                ax.plot(hist[:,i], label=label)
        ax.set_ylabel(state_dims[i])
        ax.legend()
    plt.show()

# %% [markdown]
# # Run experiments

# %%
# Constants between experiments
frequency = 250 # in Hz
run_time = 5 # in seconds
nsteps = int(run_time * frequency)
i_steps = 1

# %%
plt.rcParams["figure.figsize"] = (20,20) # make graphs BIG

# %% [markdown]
# # Natural responses

# %%
# Natural response when starting at α = 0 + noise (upright/inverted)
hist_qube, init_state = run_qube(True, zero_policy, nsteps, frequency, i_steps)
hist_ode = run_sim(init_state, zero_policy, nsteps, frequency, i_steps)

#plot_results(hists=[hist_qube], labels=['Hardware'], colors=None)
plot_results(hists=[hist_qube, hist_ode], labels=['Hardware', 'ODE'], normalize=['alpha'])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[8], line 3
#       1 # Natural response when starting at α = 0 + noise (upright/inverted)
#       2 hist_qube, init_state = run_qube(True, zero_policy, nsteps, frequency, i_steps)
# ----> 3 hist_ode = run_sim(init_state, zero_policy, nsteps, frequency, i_steps)
#       5 #plot_results(hists=[hist_qube], labels=['Hardware'], colors=None)
#       6 plot_results(hists=[hist_qube, hist_ode], labels=['Hardware', 'ODE'], normalize=['alpha'])
#
# Cell In[2], line 46, in run_sim(init_state, policy, nsteps, frequency, integration_steps)
#      43 a_hist = [a]
#      45 for i in range(nsteps):
# ---> 46     s = qube.step(a)
#      47     a = policy(s, step=i+1, frequency=frequency)
#      49     s_hist.append(s) # States
#
# File ~/quanser-openai-driver/gym_brt/quanser/qube_interfaces.py:175, in QubeSimulator.step(self, action, led)
#     173 def step(self, action, led=None):
#     174     action = np.clip(action, -self._max_voltage, self._max_voltage)
# --> 175     self.state = self._forward_model(
#     176         *self.state, action, self._dt, self._integration_steps
#     177     )
#     178     return self.state
#
# File ~/quanser-openai-driver/gym_brt/quanser/qube_simulator.py:52, in forward_model_ode(theta, alpha, theta_dot, alpha_dot, Vm, dt, integration_steps)
#      49 t = np.linspace(0.0, dt, 2)  # TODO: add and check integration steps here
#      51 state = np.array([theta, alpha, theta_dot, alpha_dot])
# ---> 52 next_state = np.array(odeint(diff_forward_model_ode, state, t, args=(Vm, dt)))[1, :]
#      53 theta, alpha, theta_dot, alpha_dot = next_state
#      55 theta = ((theta + np.pi) % (2 * np.pi)) - np.pi
#
# File ~/quanser-openai-driver/venv/lib/python3.11/site-packages/scipy/integrate/_odepack_py.py:243, in odeint(func, y0, t, args, Dfun, col_deriv, full_output, ml, mu, rtol, atol, tcrit, h0, hmax, hmin, ixpr, mxstep, mxhnil, mxordn, mxords, printmessg, tfirst)
#     241 t = copy(t)
#     242 y0 = copy(y0)
# --> 243 output = _odepack.odeint(func, y0, t, args, Dfun, col_deriv, ml, mu,
#     244                          full_output, rtol, atol, tcrit, h0, hmax, hmin,
#     245                          ixpr, mxstep, mxhnil, mxordn, mxords,
#     246                          int(bool(tfirst)))
#     247 if output[-1] < 0:
#     248     warning_msg = (f"{_msgs[output[-1]]} Run with full_output = 1 to "
#     249                    f"get quantitative information.")
#
# File ~/quanser-openai-driver/gym_brt/quanser/qube_simulator.py:41, in diff_forward_model_ode(state, t, action, dt)
#      38 alpha_dot_dot = (2.0*Lp*Lr*mp*(4.0*Dr*theta_dot + Lp**2*alpha_dot*mp*theta_dot*np.sin(2.0*alpha) + 2.0*Lp*Lr*alpha_dot**2*mp*np.sin(alpha) - 4.0*tau)*np.cos(alpha) - 0.5*(4.0*Jr + Lp**2*mp*np.sin(alpha)**2 + 4.0*Lr**2*mp)*(-8.0*Dp*alpha_dot + Lp**2*mp*theta_dot**2*np.sin(2.0*alpha) + 4.0*Lp*g*mp*np.sin(alpha)))/(4.0*Lp**2*Lr**2*mp**2*np.cos(alpha)**2 - (4.0*Jp + Lp**2*mp)*(4.0*Jr + Lp**2*mp*np.sin(alpha)**2 + 4.0*Lr**2*mp))
#      39 # fmt: on
# ---> 41 diff_state = np.array([theta_dot, alpha_dot, theta_dot_dot, alpha_dot_dot]).reshape(
#      42     (4,)
#      43 )
#      44 diff_state = np.array(diff_state, dtype="float64")
#      45 return diff_state
#
# ValueError: setting an array element with a sequence. The requested array has an inhomogeneous shape after 1 dimensions. The detected shape was (4,) + inhomogeneous part.

# %%
# Natural response when starting at α = π + noise (downwards/at rest)
hist_qube, init_state = run_qube(False, zero_policy, nsteps, frequency, i_steps)
hist_ode = run_sim(init_state, zero_policy, nsteps, frequency, i_steps)

plot_results(hists=[hist_qube, hist_ode], labels=['Hardware', 'ODE'], normalize=['alpha'])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[21], line 3
#       1 # Natural response when starting at α = π + noise (downwards/at rest)
#       2 hist_qube, init_state = run_qube(False, zero_policy, nsteps, frequency, i_steps)
# ----> 3 hist_ode = run_sim(init_state, zero_policy, nsteps, frequency, i_steps)
#       5 plot_results(hists=[hist_qube, hist_ode], labels=['Hardware', 'ODE'], normalize=['alpha'])
#
# Cell In[13], line 46, in run_sim(init_state, policy, nsteps, frequency, integration_steps)
#      43 a_hist = [a]
#      45 for i in range(nsteps):
# ---> 46     s = qube.step(a)
#      47     a = policy(s, step=i+1, frequency=frequency)
#      49     s_hist.append(s) # States
#
# File ~/quanser-openai-driver/gym_brt/quanser/qube_interfaces.py:175, in QubeSimulator.step(self, action, led)
#     173 def step(self, action, led=None):
#     174     action = np.clip(action, -self._max_voltage, self._max_voltage)
# --> 175     self.state = self._forward_model(
#     176         *self.state, action, self._dt, self._integration_steps
#     177     )
#     178     return self.state
#
# File ~/quanser-openai-driver/gym_brt/quanser/qube_simulator.py:52, in forward_model_ode(theta, alpha, theta_dot, alpha_dot, Vm, dt, integration_steps)
#      49 t = np.linspace(0.0, dt, 2)  # TODO: add and check integration steps here
#      51 state = np.array([theta, alpha, theta_dot, alpha_dot])
# ---> 52 next_state = np.array(odeint(diff_forward_model_ode, state, t, args=(Vm, dt)))[1, :]
#      53 theta, alpha, theta_dot, alpha_dot = next_state
#      55 theta = ((theta + np.pi) % (2 * np.pi)) - np.pi
#
# File ~/quanser-openai-driver/venv/lib/python3.11/site-packages/scipy/integrate/_odepack_py.py:243, in odeint(func, y0, t, args, Dfun, col_deriv, full_output, ml, mu, rtol, atol, tcrit, h0, hmax, hmin, ixpr, mxstep, mxhnil, mxordn, mxords, printmessg, tfirst)
#     241 t = copy(t)
#     242 y0 = copy(y0)
# --> 243 output = _odepack.odeint(func, y0, t, args, Dfun, col_deriv, ml, mu,
#     244                          full_output, rtol, atol, tcrit, h0, hmax, hmin,
#     245                          ixpr, mxstep, mxhnil, mxordn, mxords,
#     246                          int(bool(tfirst)))
#     247 if output[-1] < 0:
#     248     warning_msg = (f"{_msgs[output[-1]]} Run with full_output = 1 to "
#     249                    f"get quantitative information.")
#
# File ~/quanser-openai-driver/gym_brt/quanser/qube_simulator.py:41, in diff_forward_model_ode(state, t, action, dt)
#      38 alpha_dot_dot = (2.0*Lp*Lr*mp*(4.0*Dr*theta_dot + Lp**2*alpha_dot*mp*theta_dot*np.sin(2.0*alpha) + 2.0*Lp*Lr*alpha_dot**2*mp*np.sin(alpha) - 4.0*tau)*np.cos(alpha) - 0.5*(4.0*Jr + Lp**2*mp*np.sin(alpha)**2 + 4.0*Lr**2*mp)*(-8.0*Dp*alpha_dot + Lp**2*mp*theta_dot**2*np.sin(2.0*alpha) + 4.0*Lp*g*mp*np.sin(alpha)))/(4.0*Lp**2*Lr**2*mp**2*np.cos(alpha)**2 - (4.0*Jp + Lp**2*mp)*(4.0*Jr + Lp**2*mp*np.sin(alpha)**2 + 4.0*Lr**2*mp))
#      39 # fmt: on
# ---> 41 diff_state = np.array([theta_dot, alpha_dot, theta_dot_dot, alpha_dot_dot]).reshape(
#      42     (4,)
#      43 )
#      44 diff_state = np.array(diff_state, dtype="float64")
#      45 return diff_state
#
# ValueError: setting an array element with a sequence. The requested array has an inhomogeneous shape after 1 dimensions. The detected shape was (4,) + inhomogeneous part.

# %% [markdown]
# # Forced response

# %%
# Focred responce when starting at α = π + noise (downwards/at rest), and using a constant policy
hist_qube, init_state = run_qube(False, constant_policy, nsteps, frequency, i_steps)
hist_ode = run_sim(init_state, constant_policy, nsteps, frequency, i_steps)

plot_results(hists=[hist_qube, hist_ode], labels=['Hardware', 'ODE'], normalize=['alpha'])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[22], line 3
#       1 # Focred responce when starting at α = π + noise (downwards/at rest), and using a constant policy
#       2 hist_qube, init_state = run_qube(False, constant_policy, nsteps, frequency, i_steps)
# ----> 3 hist_ode = run_sim(init_state, constant_policy, nsteps, frequency, i_steps)
#       5 plot_results(hists=[hist_qube, hist_ode], labels=['Hardware', 'ODE'], normalize=['alpha'])
#
# Cell In[13], line 46, in run_sim(init_state, policy, nsteps, frequency, integration_steps)
#      43 a_hist = [a]
#      45 for i in range(nsteps):
# ---> 46     s = qube.step(a)
#      47     a = policy(s, step=i+1, frequency=frequency)
#      49     s_hist.append(s) # States
#
# File ~/quanser-openai-driver/gym_brt/quanser/qube_interfaces.py:175, in QubeSimulator.step(self, action, led)
#     173 def step(self, action, led=None):
#     174     action = np.clip(action, -self._max_voltage, self._max_voltage)
# --> 175     self.state = self._forward_model(
#     176         *self.state, action, self._dt, self._integration_steps
#     177     )
#     178     return self.state
#
# File ~/quanser-openai-driver/gym_brt/quanser/qube_simulator.py:52, in forward_model_ode(theta, alpha, theta_dot, alpha_dot, Vm, dt, integration_steps)
#      49 t = np.linspace(0.0, dt, 2)  # TODO: add and check integration steps here
#      51 state = np.array([theta, alpha, theta_dot, alpha_dot])
# ---> 52 next_state = np.array(odeint(diff_forward_model_ode, state, t, args=(Vm, dt)))[1, :]
#      53 theta, alpha, theta_dot, alpha_dot = next_state
#      55 theta = ((theta + np.pi) % (2 * np.pi)) - np.pi
#
# File ~/quanser-openai-driver/venv/lib/python3.11/site-packages/scipy/integrate/_odepack_py.py:243, in odeint(func, y0, t, args, Dfun, col_deriv, full_output, ml, mu, rtol, atol, tcrit, h0, hmax, hmin, ixpr, mxstep, mxhnil, mxordn, mxords, printmessg, tfirst)
#     241 t = copy(t)
#     242 y0 = copy(y0)
# --> 243 output = _odepack.odeint(func, y0, t, args, Dfun, col_deriv, ml, mu,
#     244                          full_output, rtol, atol, tcrit, h0, hmax, hmin,
#     245                          ixpr, mxstep, mxhnil, mxordn, mxords,
#     246                          int(bool(tfirst)))
#     247 if output[-1] < 0:
#     248     warning_msg = (f"{_msgs[output[-1]]} Run with full_output = 1 to "
#     249                    f"get quantitative information.")
#
# File ~/quanser-openai-driver/gym_brt/quanser/qube_simulator.py:41, in diff_forward_model_ode(state, t, action, dt)
#      38 alpha_dot_dot = (2.0*Lp*Lr*mp*(4.0*Dr*theta_dot + Lp**2*alpha_dot*mp*theta_dot*np.sin(2.0*alpha) + 2.0*Lp*Lr*alpha_dot**2*mp*np.sin(alpha) - 4.0*tau)*np.cos(alpha) - 0.5*(4.0*Jr + Lp**2*mp*np.sin(alpha)**2 + 4.0*Lr**2*mp)*(-8.0*Dp*alpha_dot + Lp**2*mp*theta_dot**2*np.sin(2.0*alpha) + 4.0*Lp*g*mp*np.sin(alpha)))/(4.0*Lp**2*Lr**2*mp**2*np.cos(alpha)**2 - (4.0*Jp + Lp**2*mp)*(4.0*Jr + Lp**2*mp*np.sin(alpha)**2 + 4.0*Lr**2*mp))
#      39 # fmt: on
# ---> 41 diff_state = np.array([theta_dot, alpha_dot, theta_dot_dot, alpha_dot_dot]).reshape(
#      42     (4,)
#      43 )
#      44 diff_state = np.array(diff_state, dtype="float64")
#      45 return diff_state
#
# ValueError: setting an array element with a sequence. The requested array has an inhomogeneous shape after 1 dimensions. The detected shape was (4,) + inhomogeneous part.

# %%
# Forced response when starting at α = π + noise (downwards/at rest), and using a policy that 
# switches direction every 85 steps
hist_qube, init_state = run_qube(False, square_wave_policy, nsteps, frequency, i_steps)
hist_ode = run_sim(init_state, square_wave_policy, nsteps, frequency, i_steps)

plot_results(hists=[hist_qube, hist_ode], labels=['Hardware', 'ODE'], normalize=['alpha'])

# %% [markdown]
# # PD controller (starting inverted)

# %%
# PD controller to hold when starting at α = 0 + noise (inverted)
hist_qube, init_state = run_qube(True, pd_control_policy, nsteps, frequency, i_steps)
hist_ode = run_sim(init_state, pd_control_policy, nsteps, frequency, i_steps)

plot_results(hists=[hist_qube, hist_ode], labels=['Hardware', 'ODE'], colors=None)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[9], line 3
#       1 # PD controller to hold when starting at α = 0 + noise (inverted)
#       2 hist_qube, init_state = run_qube(True, pd_control_policy, nsteps, frequency, i_steps)
# ----> 3 hist_ode = run_sim(init_state, pd_control_policy, nsteps, frequency, i_steps)
#       5 plot_results(hists=[hist_qube, hist_ode], labels=['Hardware', 'ODE'], colors=None)
#
# Cell In[2], line 46, in run_sim(init_state, policy, nsteps, frequency, integration_steps)
#      43 a_hist = [a]
#      45 for i in range(nsteps):
# ---> 46     s = qube.step(a)
#      47     a = policy(s, step=i+1, frequency=frequency)
#      49     s_hist.append(s) # States
#
# File ~/quanser-openai-driver/gym_brt/quanser/qube_interfaces.py:175, in QubeSimulator.step(self, action, led)
#     173 def step(self, action, led=None):
#     174     action = np.clip(action, -self._max_voltage, self._max_voltage)
# --> 175     self.state = self._forward_model(
#     176         *self.state, action, self._dt, self._integration_steps
#     177     )
#     178     return self.state
#
# File ~/quanser-openai-driver/gym_brt/quanser/qube_simulator.py:52, in forward_model_ode(theta, alpha, theta_dot, alpha_dot, Vm, dt, integration_steps)
#      49 t = np.linspace(0.0, dt, 2)  # TODO: add and check integration steps here
#      51 state = np.array([theta, alpha, theta_dot, alpha_dot])
# ---> 52 next_state = np.array(odeint(diff_forward_model_ode, state, t, args=(Vm, dt)))[1, :]
#      53 theta, alpha, theta_dot, alpha_dot = next_state
#      55 theta = ((theta + np.pi) % (2 * np.pi)) - np.pi
#
# File ~/quanser-openai-driver/venv/lib/python3.11/site-packages/scipy/integrate/_odepack_py.py:243, in odeint(func, y0, t, args, Dfun, col_deriv, full_output, ml, mu, rtol, atol, tcrit, h0, hmax, hmin, ixpr, mxstep, mxhnil, mxordn, mxords, printmessg, tfirst)
#     241 t = copy(t)
#     242 y0 = copy(y0)
# --> 243 output = _odepack.odeint(func, y0, t, args, Dfun, col_deriv, ml, mu,
#     244                          full_output, rtol, atol, tcrit, h0, hmax, hmin,
#     245                          ixpr, mxstep, mxhnil, mxordn, mxords,
#     246                          int(bool(tfirst)))
#     247 if output[-1] < 0:
#     248     warning_msg = (f"{_msgs[output[-1]]} Run with full_output = 1 to "
#     249                    f"get quantitative information.")
#
# File ~/quanser-openai-driver/gym_brt/quanser/qube_simulator.py:41, in diff_forward_model_ode(state, t, action, dt)
#      38 alpha_dot_dot = (2.0*Lp*Lr*mp*(4.0*Dr*theta_dot + Lp**2*alpha_dot*mp*theta_dot*np.sin(2.0*alpha) + 2.0*Lp*Lr*alpha_dot**2*mp*np.sin(alpha) - 4.0*tau)*np.cos(alpha) - 0.5*(4.0*Jr + Lp**2*mp*np.sin(alpha)**2 + 4.0*Lr**2*mp)*(-8.0*Dp*alpha_dot + Lp**2*mp*theta_dot**2*np.sin(2.0*alpha) + 4.0*Lp*g*mp*np.sin(alpha)))/(4.0*Lp**2*Lr**2*mp**2*np.cos(alpha)**2 - (4.0*Jp + Lp**2*mp)*(4.0*Jr + Lp**2*mp*np.sin(alpha)**2 + 4.0*Lr**2*mp))
#      39 # fmt: on
# ---> 41 diff_state = np.array([theta_dot, alpha_dot, theta_dot_dot, alpha_dot_dot]).reshape(
#      42     (4,)
#      43 )
#      44 diff_state = np.array(diff_state, dtype="float64")
#      45 return diff_state
#
# ValueError: setting an array element with a sequence. The requested array has an inhomogeneous shape after 1 dimensions. The detected shape was (4,) + inhomogeneous part.

# %% [markdown]
# # Energy + PD controller to flip and hold (starting down)

# %%
# Energy + PD controller to hold when starting at α = π + noise (inverted)
hist_qube, init_state = run_qube(False, flip_and_hold_policy, nsteps, frequency, i_steps)
hist_ode = run_sim(init_state, flip_and_hold_policy, nsteps, frequency, i_steps)

plot_results(hists=[hist_qube, hist_ode], labels=['Hardware', 'ODE'], normalize=['alpha'])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[10], line 3
#       1 # Energy + PD controller to hold when starting at α = π + noise (inverted)
#       2 hist_qube, init_state = run_qube(False, flip_and_hold_policy, nsteps, frequency, i_steps)
# ----> 3 hist_ode = run_sim(init_state, flip_and_hold_policy, nsteps, frequency, i_steps)
#       5 plot_results(hists=[hist_qube, hist_ode], labels=['Hardware', 'ODE'], normalize=['alpha'])
#
# Cell In[2], line 46, in run_sim(init_state, policy, nsteps, frequency, integration_steps)
#      43 a_hist = [a]
#      45 for i in range(nsteps):
# ---> 46     s = qube.step(a)
#      47     a = policy(s, step=i+1, frequency=frequency)
#      49     s_hist.append(s) # States
#
# File ~/quanser-openai-driver/gym_brt/quanser/qube_interfaces.py:175, in QubeSimulator.step(self, action, led)
#     173 def step(self, action, led=None):
#     174     action = np.clip(action, -self._max_voltage, self._max_voltage)
# --> 175     self.state = self._forward_model(
#     176         *self.state, action, self._dt, self._integration_steps
#     177     )
#     178     return self.state
#
# File ~/quanser-openai-driver/gym_brt/quanser/qube_simulator.py:52, in forward_model_ode(theta, alpha, theta_dot, alpha_dot, Vm, dt, integration_steps)
#      49 t = np.linspace(0.0, dt, 2)  # TODO: add and check integration steps here
#      51 state = np.array([theta, alpha, theta_dot, alpha_dot])
# ---> 52 next_state = np.array(odeint(diff_forward_model_ode, state, t, args=(Vm, dt)))[1, :]
#      53 theta, alpha, theta_dot, alpha_dot = next_state
#      55 theta = ((theta + np.pi) % (2 * np.pi)) - np.pi
#
# File ~/quanser-openai-driver/venv/lib/python3.11/site-packages/scipy/integrate/_odepack_py.py:243, in odeint(func, y0, t, args, Dfun, col_deriv, full_output, ml, mu, rtol, atol, tcrit, h0, hmax, hmin, ixpr, mxstep, mxhnil, mxordn, mxords, printmessg, tfirst)
#     241 t = copy(t)
#     242 y0 = copy(y0)
# --> 243 output = _odepack.odeint(func, y0, t, args, Dfun, col_deriv, ml, mu,
#     244                          full_output, rtol, atol, tcrit, h0, hmax, hmin,
#     245                          ixpr, mxstep, mxhnil, mxordn, mxords,
#     246                          int(bool(tfirst)))
#     247 if output[-1] < 0:
#     248     warning_msg = (f"{_msgs[output[-1]]} Run with full_output = 1 to "
#     249                    f"get quantitative information.")
#
# File ~/quanser-openai-driver/gym_brt/quanser/qube_simulator.py:41, in diff_forward_model_ode(state, t, action, dt)
#      38 alpha_dot_dot = (2.0*Lp*Lr*mp*(4.0*Dr*theta_dot + Lp**2*alpha_dot*mp*theta_dot*np.sin(2.0*alpha) + 2.0*Lp*Lr*alpha_dot**2*mp*np.sin(alpha) - 4.0*tau)*np.cos(alpha) - 0.5*(4.0*Jr + Lp**2*mp*np.sin(alpha)**2 + 4.0*Lr**2*mp)*(-8.0*Dp*alpha_dot + Lp**2*mp*theta_dot**2*np.sin(2.0*alpha) + 4.0*Lp*g*mp*np.sin(alpha)))/(4.0*Lp**2*Lr**2*mp**2*np.cos(alpha)**2 - (4.0*Jp + Lp**2*mp)*(4.0*Jr + Lp**2*mp*np.sin(alpha)**2 + 4.0*Lr**2*mp))
#      39 # fmt: on
# ---> 41 diff_state = np.array([theta_dot, alpha_dot, theta_dot_dot, alpha_dot_dot]).reshape(
#      42     (4,)
#      43 )
#      44 diff_state = np.array(diff_state, dtype="float64")
#      45 return diff_state
#
# ValueError: setting an array element with a sequence. The requested array has an inhomogeneous shape after 1 dimensions. The detected shape was (4,) + inhomogeneous part.

# %%
import gym
from gym_brt import QubeSwingupEnv

num_episodes = 10
num_steps = 250

with QubeSwingupEnv() as env:
    for episode in range(num_episodes):
        state = env.reset()
        for step in range(num_steps):
            action = env.action_space.sample()
            state, reward, done, _ = env.step(action)
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[12], line 2
#       1 import gym
# ----> 2 from gym_brt import QubeSwingupEnv
#       4 num_episodes = 10
#       5 num_steps = 250
#
# ImportError: cannot import name 'QubeSwingupEnv' from 'gym_brt' (/home/mt/quanser-openai-driver/gym_brt/__init__.py)

# %% [markdown]
# # Square wave + PD controller to flip and hold (starting down)
# This often seems to work on the Qube, so it should work on the sim too

# %%
# Energy + PD controller to hold when starting at α = π + noise (inverted)
hist_qube, init_state = run_qube(False, square_wave_flip_and_hold_policy, nsteps, frequency, i_steps)
hist_ode = run_sim(init_state, square_wave_flip_and_hold_policy, nsteps, frequency, i_steps)

plot_results(hists=[hist_qube, hist_ode], labels=['Hardware', 'ODE'], normalize=['alpha'])
